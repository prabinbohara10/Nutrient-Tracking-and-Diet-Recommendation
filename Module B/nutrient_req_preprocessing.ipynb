# %%
import numpy as np
import pandas as pd
import re

# %%
nutrient_data_path = "nutrient_requirements_original_format.csv"

# %%
df = pd.read_csv(nutrient_data_path)
df
# Out:
#                     Gender Age (years)  \
# 0   Infant(male or female)     under 2
# 1                   Female         2-9
# 2                     Male         2-9
# 3                   Female       10-19
# 4                     Male       10-19
# 5                   Female       20-29
# 6                     Male       20-29
# 7                   Female       30-39
# 8                     Male       30-39
# 9                   Female       40-49
# 10                    Male       40-49
# 11                  Female     50 - 59
# 12                    Male     50 - 59
# 13                  Female      60-100
# 14                    Male      60-100
#
#                                       Recommended BMI Fat( in g)  \
# 0   Refer growth chart using weight-for-length mea...    30–40 g
# 1                                          16.2- 17.8    42-58 g
# 2                                         16.4 - 17.6    42-58 g
# 3                                           17.8-22.6       65 g
# 4                                           17.6-22.5       65 g
# 5                                         18.5 – 24.9       70 g
# 6                                         18.5 – 24.9       70 g
# 7                                         18.5 – 24.9       70 g
# 8                                         18.5 – 24.9       70 g
# 9                                         18.5 – 24.9       70 g
# 10                                        18.5 – 24.9       70 g
# 11                                        18.5 – 24.9       70 g
# 12                                        18.5 – 24.9       70 g
# 13                                        22.0 – 27.0    65–70 g
# 14                                        22.0 – 27.0    65–70 g
#
#    Carbohydrates( in g) Protein( in g)  \
# 0                  95 g           11 g
# 1             169-244 g       38-113 g
# 2             169-244 g       38-113 g
# 3                 260 g        34-46 g
# 4                 260 g        34-52 g
# 5                 260 g           46 g
# 6                 260 g           56 g
# 7                 260 g           46 g
# 8                 260 g           56 g
# 9                 260 g           46 g
# 10                260 g           56 g
# 11                260 g           46 g
# 12                260 g           56 g
# 13                260 g           46 g
# 14                260 g           56 g
#
#                                  Dietary Fiber( in g)  \
# 0   not specific recommendation(introduce  fiber-r...
# 1                                             14-21 g
# 2                                             14-21 g
# 3                                                25 g
# 4                                                38 g
# 5                                                25 g
# 6                                                38 g
# 7                                                25 g
# 8                                                38 g
# 9                                                25 g
# 10                                               38 g
# 11                                               25 g
# 12                                               38 g
# 13                                            30–38 g
# 14                                            30–38 g
#
#                                      Water( in litre) Vitamin A( in mg)  \
# 0   adequate hydration from breast milk or formula...            300 µg
# 1                                     1.3- 1.7 liters        300-400 µg
# 2                                     1.3- 1.7 liters        300-400 µg
# 3                                             2.7–3 L            700 µg
# 4                                                 3 L            900 µg
# 5                                               2.7 L            0.7 mg
# 6                                               3.7 L            0.9 mg
# 7                                               2.7 L            0.7 mg
# 8                                               3.7 L            0.9 mg
# 9                                               2.7 L            0.7 mg
# 10                                              3.7 L            0.9 mg
# 11                                              2.7 L            0.7 mg
# 12                                              3.7 L            0.9 mg
# 13                                              2.7 L            0.7 mg
# 14                                                3 L            0.9 mg
#
#    Vitamin B11 (Folate)( in mg) Vitamin B12 (mg) Vitamin C Vitamin D( in mg)  \
# 0                         80 µg           0.5 µg     40 mg             10 µg
# 1                    150-200 µg       1.2-1.8 µg  15-25 mg             15 µg
# 2                    150-200 µg       1.2-1.8 µg  15-25 mg             15 µg
# 3                        400 µg           2.4 µg     65 mg             15 µg
# 4                        400 µg           2.4 µg     75 mg             15 µg
# 5                        0.4 mg           2.4 µg     75 mg             15 µg
# 6                        0.4 mg           2.4 µg     90 mg             15 µg
#  11  Vitamin C                     14 non-null     object
#  12  Vitamin D( in mg)             14 non-null     object
#  13  Vitamin E( in mg)             14 non-null     object
#  14  Vitamin K( in mg)             14 non-null     object
#  15  Calcium( in mg)               14 non-null     object
#  16  Iron( in mg)                  14 non-null     object
#  17  Magnesium( in mg)             14 non-null     object
#  18  Manganese( in mg)             14 non-null     object
# dtypes: object(19)
# memory usage: 2.2+ KB

# %%
def clean_cell(value):
    if pd.isna(value) or not isinstance(value, str):
        return value

    value = re.sub(r'\([^)]*\)', '', value)  # Remove content in parentheses
    value = re.sub(r'[µμ]g', '', value)      # Remove µg/μg
    value = re.sub(r'\sg\s?', ' ', value)    #g with space
    value = re.sub(r'\sg$', '', value)       # g at end
    value = re.sub(r'\smg\s?', ' ', value)   # mg
    value = re.sub(r'\sL\s?', ' ', value)    # L
    value = re.sub(r'\sliters', '', value)   #liters
    
    ## Remove all remaining letters
    value = re.sub(r'[a-zA-Z]', '', value)
    
    ## Clean up spaces
    value = re.sub(r'\s+', ' ', value).strip()
    
    #handling with different dash types
    if "–" in value or "-" in value:
        # Standardize dash
        value = value.replace("–", "-")
        
        # Clean up spaces around dash
        value = re.sub(r'\s*-\s*', '-', value)
        
        # Check if it's a range
        parts = value.split("-")
        if len(parts) == 2:
            # Handle empty parts or parts with only spaces
            parts = [p.strip() if p.strip() else "0" for p in parts]
            return f"{parts[0]}-{parts[1]}"
    
    return value.strip()

# %%
def clean_df(df):
    
    # Apply cleaning to all data columns
    for col in df.columns[1:]:  #Starting from the 2nd column
        df[col] = df[col].apply(clean_cell)
    
    return df

# %%
df = clean_df(df)
df
# Out:
#     Gender Age (years) Recommended BMI Fat( in g) Carbohydrates( in g)  \
# 1   Female         2-9       16.2-17.8      42-58              169-244
# 2     Male         2-9       16.4-17.6      42-58              169-244
# 3   Female       10-19       17.8-22.6         65                  260
# 4     Male       10-19       17.6-22.5         65                  260
# 5   Female       20-29       18.5-24.9         70                  260
# 6     Male       20-29       18.5-24.9         70                  260
# 7   Female       30-39       18.5-24.9         70                  260
# 8     Male       30-39       18.5-24.9         70                  260
# 9   Female       40-49       18.5-24.9         70                  260
# 10    Male       40-49       18.5-24.9         70                  260
# 11  Female       50-59       18.5-24.9         70                  260
# 12    Male       50-59       18.5-24.9         70                  260
# 13  Female      60-100       22.0-27.0      65-70                  260
# 14    Male      60-100       22.0-27.0      65-70                  260
#
#    Protein( in g) Dietary Fiber( in g) Water( in litre) Vitamin A( in mg)  \
# 1          38-113                14-21          1.3-1.7           300-400
# 2          38-113                14-21          1.3-1.7           300-400
# 3           34-46                   25            2.7-3               700
# 4           34-52                   38                3               900
# 5              46                   25              2.7               0.7
# 6              56                   38              3.7               0.9
# 7              46                   25              2.7               0.7
# 8              56                   38              3.7               0.9
# 9              46                   25              2.7               0.7
# 10             56                   38              3.7               0.9
# 11             46                   25              2.7               0.7
# 12             56                   38              3.7               0.9
# 13             46                30-38              2.7               0.7
# 14             56                30-38                3               0.9
#
#    Vitamin B11 (Folate)( in mg) Vitamin B12 (mg) Vitamin C Vitamin D( in mg)  \
# 1                       150-200          1.2-1.8     15-25                15
# 2                       150-200          1.2-1.8     15-25                15
# 3                           400              2.4        65                15
# 4                           400              2.4        75                15
# 5                           0.4              2.4        75                15
# 6                           0.4              2.4        90                15
# 7                           0.4              2.4        75                15
# 8                           0.4              2.4        90                15
# 9                           0.4              2.4        75                15
# 10                          0.4              2.4        90                15
# 11                          0.4              2.4        75                15
# 12                          0.4              2.4        90                15
# 13                          0.4              2.4        75                15
# 14                          0.4              2.4        90                15
#
#    Vitamin E( in mg) Vitamin K( in mg) Calcium( in mg) Iron( in mg)  \
# 1                6-7             55-60        700-1000         7-10
# 2                6-7             55-60        700-1000         7-10
# 3                 15                75            1300           11
# 4                 15                75            1300           15
# 5                 15              0.09            1000           18
# 6                 15              0.12            1000            8
# 7                 15              0.09            1000           18
# 8                 15              0.12            1000            8
# 9                 15              0.09            1000           18
# 10                15              0.12            1000            8
# 11                15              0.09            1200            8
# 12                15              0.12            1000            8
# 13                15              0.09            1200            8
# 14                15              0.12            1000            8
#
#    Magnesium( in mg) Manganese( in mg)
# 1             80-130           1.2-1.5
# 2             80-130           1.2-1.5
# 3                360               1.6
# 4                410               2.2
# 5                320               1.8
# 6                420               2.3
# 7                320               1.8
# 8                420               2.3
# 9                320               1.8
# 10               420               2.3
# 11               320               1.8
# 12               420               2.3
# 13               320               1.8
# 14               420               2.3

# %%
# Out:
# [['2', '9'],
#  ['2', '9'],
#  ['10', '19'],
#  ['10', '19'],
#  ['20', '29'],
#  ['20', '29'],
#  ['30', '39'],
#  ['30', '39'],
#  ['40', '49'],
#  ['40', '49'],
#  ['50', '59'],
#  ['50', '59'],
#  ['60', '100'],
#  ['60', '100']]

# %%
age_ranges = [age.split("-") for age in df["Age (years)"]]
age_ranges
# Out:
# [['2', '9'],
#  ['2', '9'],
#  ['10', '19'],
#  ['10', '19'],
#  ['20', '29'],
#  ['20', '29'],
#  ['30', '39'],
#  ['30', '39'],
#  ['40', '49'],
#  ['40', '49'],
#  ['50', '59'],
#  ['50', '59'],
#  ['60', '100'],
#  ['60', '100']]

# %%
class PatientNutrient:
    def __init__(self, gender, age, bmi):
        self.gender = gender
        self.age = age
        self.bmi = bmi

    def get_nutrient_requirement(self, df):
        age_ranges = [age.split("-") for age in df["Age (years)"]]
        age_group = None
        for i, age_range in enumerate(age_ranges):
            if int(age_range[0]) <= self.age <= int(age_range[1]):
                age_group = df["Age (years)"][i]
        
        if age_group:
            filtered_row = df[(df["Age (years)"] == age_group) & (df['Gender'] == self.gender)]
            return filtered_row.iloc[0].to_dict()
        
        return None

# %%
patient1 = PatientNutrient("Male", 25, 34)
patient1.get_nutrient_requirement(df)
# Out:
# {'Gender': 'Male',
#  'Age (years)': '20-29',
#  'Recommended BMI': '18.5-24.9',
#  'Fat( in g)': '70',
#  'Carbohydrates( in g)': '260',
#  'Protein( in g)': '56',
#  'Dietary Fiber( in g)': '38',
#  'Water( in litre)': '3.7',
#  'Vitamin A( in mg)': '0.9',
#  'Vitamin B11 (Folate)( in mg)': '0.4',
#  'Vitamin B12 (mg)': '2.4',
#  'Vitamin C': '90',
#  'Vitamin D( in mg)': '15',
#  'Vitamin E( in mg)': '15',
#  'Vitamin K( in mg)': '0.12',
#  'Calcium( in mg)': '1000',
#  'Iron( in mg)': '8',
#  'Magnesium( in mg)': '420',
#  'Manganese( in mg)': '2.3'}
